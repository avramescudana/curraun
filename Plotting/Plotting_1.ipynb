# %% [markdown]
# # Computing the effect of alpha
#
# In this notebook we compute the the effect of alpha.
#
# m_noise is still not implemeneted in this data and plots.
#
# $g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$                       for $\alpha = $ fixed,     $N = 32, 64, 128, 256, 512, 1024 $
#
# $g^2 \mu \tau$    vs    $\frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$     for $\alpha = $ fixed,     $N = 32, 64, 128, 256, 512, 1024 $
#
# $g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$                       for $N= $ fixed,            $\alpha =  0.1, 0.01, 0.001, 0.0001, 0.00001$
#
# $g^2 \mu \tau$    vs    $\frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$     for $N= $ fixed,            $\alpha =  0.1, 0.01, 0.001, 0.0001, 0.00001$

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

from matplotlib import rc

# rc('text', usetex=True)
plt.rcParams["figure.figsize"] = (10, 7)
plt.rcParams.update({'font.size':18})

base_path = "/home/pooja/Desktop/Research/curraun/notebooks/Plots_Data_18042025/Data_files/"




# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for alpha = 0.1, N=32, 64, 128, 256, 512, 1024
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.1
filename = "data_tau_diffEeta_N32_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 32 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.1
filename = "data_tau_diffEeta_N64_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 64 $, $\alpha = 0.1 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.1
filename = "data_tau_diffEeta_N128_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.1 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.1
filename = "data_tau_diffEeta_N256_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 256 $, $\alpha = 0.1 $", color='orange', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.1
filename = "data_tau_diffEeta_N512_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 512 $, $\alpha = 0.1 $", color='cyan', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.1
filename = "data_tau_diffEeta_N1024_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 1024 $, $\alpha = 0.1 $", color='brown', linestyle="dashed", linewidth=2.0)
      
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_Ndiff_alpha01.png', dpi=600)                              # Save the plot
plt.show()
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!



# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for alpha = 0.01, N=32, 64, 128, 256, 512, 1024
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.01
filename = "data_tau_diffEeta_N32_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 32 $, $\alpha = 0.01 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.01
filename = "data_tau_diffEeta_N64_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 64 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.01
filename = "data_tau_diffEeta_N128_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.01 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.01
filename = "data_tau_diffEeta_N256_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 256 $, $\alpha = 0.01 $", color='orange', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.01
filename = "data_tau_diffEeta_N512_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 512 $, $\alpha = 0.01 $", color='cyan', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.01
filename = "data_tau_diffEeta_N1024_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 1024 $, $\alpha = 0.01 $", color='brown', linestyle="dashed", linewidth=2.0)
      
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_Ndiff_alpha001.png', dpi=600)                              # Save the plot
plt.show()
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++



# ******************************************************************************************************************************
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for alpha = 0.001, N = 32, 64, 128, 256, 512, 1024
# ******************************************************************************************************************************
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.001
filename = "data_tau_diffEeta_N32_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 32 $, $\alpha = 0.001 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.001
filename = "data_tau_diffEeta_N64_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 64 $, $\alpha = 0.001 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.001
filename = "data_tau_diffEeta_N128_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.001
filename = "data_tau_diffEeta_N256_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 256 $, $\alpha = 0.001 $", color='orange', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.001
filename = "data_tau_diffEeta_N512_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 512 $, $\alpha = 0.001 $", color='cyan', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.001
filename = "data_tau_diffEeta_N1024_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 1024 $, $\alpha = 0.001 $", color='brown', linestyle="dashed", linewidth=2.0)
      
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_Ndiff_alpha0001.png', dpi=600)                              # Save the plot
plt.show()
# ******************************************************************************************************************************
# ******************************************************************************************************************************



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for alpha = 0.0001, N = 32, 64, 128, 256, 512, 1024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.0001
filename = "data_tau_diffEeta_N32_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 32 $, $\alpha = 0.0001 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.0001
filename = "data_tau_diffEeta_N64_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 64 $, $\alpha = 0.0001 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.0001
filename = "data_tau_diffEeta_N128_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.0001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.0001
filename = "data_tau_diffEeta_N256_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 256 $, $\alpha = 0.0001 $", color='orange', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.0001
filename = "data_tau_diffEeta_N512_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 512 $, $\alpha = 0.0001 $", color='cyan', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.0001
filename = "data_tau_diffEeta_N1024_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 1024 $, $\alpha = 0.0001 $", color='brown', linestyle="dashed", linewidth=2.0)
      
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_Ndiff_alpha00001.png', dpi=600)                              # Save the plot
plt.show()
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for alpha = 0.00001, N = 32, 64, 128, 256, 512, 1024
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.00001
filename = "data_tau_diffEeta_N32_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 32 $, $\alpha = 0.00001 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.00001
filename = "data_tau_diffEeta_N64_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 64 $, $\alpha = 0.00001 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.00001
filename = "data_tau_diffEeta_N128_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.00001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.00001
filename = "data_tau_diffEeta_N256_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 256 $, $\alpha = 0.00001 $", color='orange', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.00001
filename = "data_tau_diffEeta_N512_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 512 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.00001
filename = "data_tau_diffEeta_N1024_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 1024 $, $\alpha = 0.00001 $", color='brown', linestyle="dashed", linewidth=2.0)
      
"""
df = pd.read_csv("data_tau_diffEeta_N128_alpha000001.csv")
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.00001 $", color='blue', linestyle="dashed", linewidth=2.0)
"""


plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_Ndiff_alpha000001.png', dpi=600)                              # Save the plot
plt.show()
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

from matplotlib import rc

# rc('text', usetex=True)
plt.rcParams["figure.figsize"] = (10, 7)
plt.rcParams.update({'font.size':18})

base_path = "/home/pooja/Desktop/Research/curraun/notebooks/Plots_Data_18042025/Data_files/"




# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Plotting:    1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for alpha = 0.1, N=32, 64, 128, 256, 512, 1024
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N32_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 32 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N64_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 64 $, $\alpha = 0.1 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N128_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.1 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N256_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 256 $, $\alpha = 0.1 $", color='orange', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N512_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 512 $, $\alpha = 0.1 $", color='cyan', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N1024_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 1024 $, $\alpha = 0.1 $", color='brown', linestyle="dashed", linewidth=2.0)
      
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_Ndiff_alpha01.png', dpi=600)                              # Save the plot
plt.show()
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!



# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Plotting:   1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for alpha = 0.01, N=32, 64, 128, 256, 512, 1024
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N32_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 32 $, $\alpha = 0.01 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N64_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 64 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N128_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.01 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N256_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 256 $, $\alpha = 0.01 $", color='orange', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N512_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 512 $, $\alpha = 0.01 $", color='cyan', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N1024_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 1024 $, $\alpha = 0.01 $", color='brown', linestyle="dashed", linewidth=2.0)


     
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale         
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_Ndiff_alpha001.png', dpi=600)                              # Save the plot
plt.show()
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++



# ******************************************************************************************************************************
# Plotting:    1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for alpha = 0.001, N = 32, 64, 128, 256, 512, 1024
# ******************************************************************************************************************************
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N32_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 32 $, $\alpha = 0.001 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N64_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 64 $, $\alpha = 0.001 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N128_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N256_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 256 $, $\alpha = 0.001 $", color='orange', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N512_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 512 $, $\alpha = 0.001 $", color='cyan', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N1024_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 1024 $, $\alpha = 0.001 $", color='brown', linestyle="dashed", linewidth=2.0)
      
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_Ndiff_alpha0001.png', dpi=600)                              # Save the plot
plt.show()
# ******************************************************************************************************************************
# ******************************************************************************************************************************



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Plotting:    1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for alpha = 0.0001, N = 32, 64, 128, 256, 512, 1024
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N32_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 32 $, $\alpha = 0.0001 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N64_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 64 $, $\alpha = 0.0001 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N128_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.0001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N256_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 256 $, $\alpha = 0.0001 $", color='orange', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N512_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 512 $, $\alpha = 0.0001 $", color='cyan', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N1024_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 1024 $, $\alpha = 0.0001 $", color='brown', linestyle="dashed", linewidth=2.0)
      
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_Ndiff_alpha00001.png', dpi=600)                              # Save the plot
plt.show()
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# Plotting:    1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for alpha = 0.00001, N = 32, 64, 128, 256, 512, 1024
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N32_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 32 $, $\alpha = 0.00001 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N64_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 64 $, $\alpha = 0.00001 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N128_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.00001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N256_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 256 $, $\alpha = 0.00001 $", color='orange', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N512_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 512 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N1024_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 1024 $, $\alpha = 0.00001 $", color='brown', linestyle="dashed", linewidth=2.0)
      
"""
df = pd.read_csv("data_tau_diffEeta_alpha2_N128_alpha000001.csv")
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.00001 $", color='blue', linestyle="dashed", linewidth=2.0)
"""


plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_Ndiff_alpha000001.png', dpi=600)                              # Save the plot
plt.show()
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

from matplotlib import rc

# rc('text', usetex=True)
plt.rcParams["figure.figsize"] = (10, 7)
plt.rcParams.update({'font.size':18})

base_path = "/home/pooja/Desktop/Research/curraun/notebooks/Plots_Data_18042025/Data_files/"




# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 32 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.1
filename = "data_tau_diffEeta_N32_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 32 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 32, alpha = 0.01
filename = "data_tau_diffEeta_N32_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 32 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 32, alpha = 0.001
filename = "data_tau_diffEeta_N32_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 32 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 32, alpha = 0.0001
filename = "data_tau_diffEeta_N32_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 32 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 32, alpha = 0.00001
filename = "data_tau_diffEeta_N32_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 32 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale     
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_N32_alphadiff.png', dpi=600)                                      # Save the plot
plt.show()
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!



# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 64 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 64, alpha = 0.1
filename = "data_tau_diffEeta_N64_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 64 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.01
filename = "data_tau_diffEeta_N64_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 64 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.001
filename = "data_tau_diffEeta_N64_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 64 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.0001
filename = "data_tau_diffEeta_N64_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 64 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.00001
filename = "data_tau_diffEeta_N64_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 64 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale     
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_N64_alphadiff.png', dpi=600)                                      # Save the plot
plt.show()
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++



# ******************************************************************************************************************************
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 128 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# ******************************************************************************************************************************
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 128, alpha = 0.1
filename = "data_tau_diffEeta_N128_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.01
filename = "data_tau_diffEeta_N128_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.001
filename = "data_tau_diffEeta_N128_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.0001
filename = "data_tau_diffEeta_N128_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.00001
filename = "data_tau_diffEeta_N128_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 128 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale    
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_N128_alphadiff.png', dpi=600)                                     # Save the plot
plt.show()
# ******************************************************************************************************************************
# ******************************************************************************************************************************



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 256 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 256, alpha = 0.1
filename = "data_tau_diffEeta_N256_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 256 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.01
filename = "data_tau_diffEeta_N256_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 256 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.001
filename = "data_tau_diffEeta_N256_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 256 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.0001
filename = "data_tau_diffEeta_N256_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 256 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.00001
filename = "data_tau_diffEeta_N256_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 256 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale    
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_N256_alphadiff.png', dpi=600)                                     # Save the plot
plt.show()
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 512 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 512, alpha = 0.1
filename = "data_tau_diffEeta_N512_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 512 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.01
filename = "data_tau_diffEeta_N512_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 512 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.001
filename = "data_tau_diffEeta_N512_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 512 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.0001
filename = "data_tau_diffEeta_N512_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 512 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.00001
filename = "data_tau_diffEeta_N512_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 512 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale    
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_N512_alphadiff.png', dpi=600)                                     # Save the plot
plt.show()
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////








# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
# Plotting:    Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 1024 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
plt.title(r"$g^2 \mu \tau$    vs    $ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")               # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                       # Plot X-Axis Label
plt.ylabel(r"$ \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                                      # Plot Y-Axis Label

# Plotting for N = 1024, alpha = 0.1
filename = "data_tau_diffEeta_N1024_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 1024 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.01
filename = "data_tau_diffEeta_N1024_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 1024 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.001
filename = "data_tau_diffEeta_N1024_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 1024 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.0001
filename = "data_tau_diffEeta_N1024_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 1024 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.00001
filename = "data_tau_diffEeta_N1024_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta"], label=rf"$N = 1024 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
plt.ylim(0.0, 0.000001)                                                                                      # To change the y scale    
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_N1024_alphadiff.png', dpi=600)                                     # Save the plot
plt.show()
# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

from matplotlib import rc

# rc('text', usetex=True)
plt.rcParams["figure.figsize"] = (10, 7)
plt.rcParams.update({'font.size':18})

base_path = "/home/pooja/Desktop/Research/curraun/notebooks/Plots_Data_18042025/Data_files/"




# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Plotting:    1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 32 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 32, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N32_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 32 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 32, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N32_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 32 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 32, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N32_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 32 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 32, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N32_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 32 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 32, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N32_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 32 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale     
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_N32_alphadiff.png', dpi=600)                                      # Save the plot
plt.show()
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!



# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Plotting:    1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 64 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 64, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N64_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 64 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N64_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 64 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N64_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 64 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N64_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 64 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 64, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N64_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 64 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale     
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_N64_alphadiff.png', dpi=600)                                      # Save the plot
plt.show()
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++



# ******************************************************************************************************************************
# Plotting:    1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 128 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# ******************************************************************************************************************************
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 128, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N128_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N128_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N128_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N128_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 128, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N128_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 128 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale    
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_N128_alphadiff.png', dpi=600)                                     # Save the plot
plt.show()
# ******************************************************************************************************************************
# ******************************************************************************************************************************



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Plotting:    1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 256 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 256, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N256_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 256 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N256_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 256 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N256_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 256 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N256_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 256 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 256, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N256_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 256 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale    
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_N256_alphadiff.png', dpi=600)                                     # Save the plot
plt.show()
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# Plotting:    1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 512 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 512, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N512_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 512 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N512_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 512 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N512_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 512 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N512_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 512 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 512, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N512_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 512 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)


      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.0001)                                                                                      # To change the y scale    
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_N512_alphadiff.png', dpi=600)                                     # Save the plot
plt.show()
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////








# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
# Plotting:    1/alpha² Tr(E' - E)^2 / Tr(E^2)     vs     g^2 mu tau         for  N = 1024 and alpha = 0.1, 0.01, 0.001, 0.0001, 0.00001
# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
plt.title(r"$g^2 \mu \tau$    vs    $ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")    # Plot title
plt.xlabel(r"$g^2 \mu \tau$")                                                                                               # Plot X-Axis Label
plt.ylabel(r"$ \frac{1}{\alpha^2} \mathrm {\frac{Tr(E'_{\eta} - E_{\eta})^2}{Tr(E_{\eta}^2)} }$")                           # Plot Y-Axis Label

# Plotting for N = 1024, alpha = 0.1
filename = "data_tau_diffEeta_alpha2_N1024_alpha01.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 1024 $, $\alpha = 0.1 $", color='red', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.01
filename = "data_tau_diffEeta_alpha2_N1024_alpha001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 1024 $, $\alpha = 0.01 $", color='green', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.001
filename = "data_tau_diffEeta_alpha2_N1024_alpha0001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 1024 $, $\alpha = 0.001 $", color='blue', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.0001
filename = "data_tau_diffEeta_alpha2_N1024_alpha00001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 1024 $, $\alpha = 0.0001 $", color='pink', linestyle="dashed", linewidth=2.0)

# Plotting for N = 1024, alpha = 0.00001
filename = "data_tau_diffEeta_alpha2_N1024_alpha000001.csv"
file_path = os.path.join(base_path, filename)
df = pd.read_csv(file_path)
plt.plot(df["tau"], df["diff_Eeta_alpha2"], label=rf"$N = 1024 $, $\alpha = 0.00001 $", color='cyan', linestyle="dashed", linewidth=2.0)

      
#plt.xlim(0.0, 200)                                                                                         # To change the x scale          
#plt.ylim(0.0, 0.000001)                                                                                      # To change the y scale    
plt.legend()
plt.savefig('ComparePlot_g2mutau_diffEeta_alpha2_N1024_alphadiff.png', dpi=600)                                     # Save the plot
plt.show()
# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
