# %% [markdown]
# # Saving the data to data files and plotting them
#
# In this notebook, we save the data using data frames of pandas.
#
# NOTE: This works only when the code is run before it. otherwise, it gives error,

# %%
# ----------------------- Saving data to a CSV file and plotting from file using pandas -----------------------

x_tau_g2mu_Latt    =  tau_g2mu_Latt

y_Tr_ELdiff2_Mean  =  Glasma["Tr_ELdiff2_Mean"]
y_Tr_ELdiff2_Var   =  Glasma["Tr_ELdiff2_Variance"]
y_Tr_ELdiff2_StD   =  Glasma["Tr_ELdiff2_StD"]
y_Tr_ELdiff2_Error =  Glasma["Tr_ELdiff2_Error"]        # # Calculate the error bars using the variance

y_Tr_ELdiff2_by_alpha2_Mean  =  Glasma["Tr_ELdiff2_by_alpha2_Mean"]
y_Tr_ELdiff2_by_alpha2_Var   =  Glasma["Tr_ELdiff2_by_alpha2_Variance"]
y_Tr_ELdiff2_by_alpha2_StD   =  Glasma["Tr_ELdiff2_by_alpha2_StD"]
y_Tr_ELdiff2_by_alpha2_Error =  Glasma["Tr_ELdiff2_by_alpha2_Error"]

y_Ratio_Tr_ELdiff2_Tr_EL2_Mean  =  Glasma["Ratio_Tr_ELdiff2_Tr_EL2_Mean"]
y_Ratio_Tr_ELdiff2_Tr_EL2_Var   =  Glasma["Ratio_Tr_ELdiff2_Tr_EL2_Variance"]
y_Ratio_Tr_ELdiff2_Tr_EL2_StD   =  Glasma["Ratio_Tr_ELdiff2_Tr_EL2_StD"]
y_Ratio_Tr_ELdiff2_Tr_EL2_Error =  Glasma["Ratio_Tr_ELdiff2_Tr_EL2_Error"]

y_Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Mean  =  Glasma["Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Mean"]
y_Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Var   =  Glasma["Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Variance"]
y_Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_StD   =  Glasma["Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_StD"]
y_Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Error =  Glasma["Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Error"]

y_Tr_BLdiff2_Mean  =  Glasma["Tr_BLdiff2_Mean"]
y_Tr_BLdiff2_Var   =  Glasma["Tr_BLdiff2_Variance"]
y_Tr_BLdiff2_StD   =  Glasma["Tr_BLdiff2_StD"]
y_Tr_BLdiff2_Error =  Glasma["Tr_BLdiff2_Error"]

y_Tr_BLdiff2_by_alpha2_Mean  =  Glasma["Tr_BLdiff2_by_alpha2_Mean"]
y_Tr_BLdiff2_by_alpha2_Var   =  Glasma["Tr_BLdiff2_by_alpha2_Variance"]
y_Tr_BLdiff2_by_alpha2_StD   =  Glasma["Tr_BLdiff2_by_alpha2_StD"]
y_Tr_BLdiff2_by_alpha2_Error =  Glasma["Tr_BLdiff2_by_alpha2_Error"]

y_Ratio_Tr_BLdiff2_Tr_BL2_Mean  =  Glasma["Ratio_Tr_BLdiff2_Tr_BL2_Mean"]
y_Ratio_Tr_BLdiff2_Tr_BL2_Var   =  Glasma["Ratio_Tr_BLdiff2_Tr_BL2_Variance"]
y_Ratio_Tr_BLdiff2_Tr_BL2_StD   =  Glasma["Ratio_Tr_BLdiff2_Tr_BL2_StD"]
y_Ratio_Tr_BLdiff2_Tr_BL2_Error =  Glasma["Ratio_Tr_BLdiff2_Tr_BL2_Error"]

y_Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Mean  =  Glasma["Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Mean"]
y_Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Var   =  Glasma["Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Variance"]
y_Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_StD   =  Glasma["Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_StD"]
y_Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Error =  Glasma["Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Error"]


# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ #
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ Generating dynamic labels and file names +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ #
if Option_Noise_Type == 0:
    label_dynamic = rf"$Noise~Type = {Noise_Type_String}$, $\alpha = {alpha_String}$,  $N = {N_T}$, $L = {L_String}$, $g^2\mu = {g2mu_String}$, $N_{{events}} = {N_Events}$"

 
    # Define common suffix for file names once
    common_suffix = f"Noise{Noise_Type_String}_alpha{alpha_String}_N{N_T}_L{L_String}_g2mu{g2mu_String}_Nevents{N_Events}"

    data_filename_EL_1 = f"data_tau_TrELdiff2_{common_suffix}.csv"  
    data_filename_EL_2 = f"data_tau_TrELdiff2byalpha2_{common_suffix}.csv"

    data_filename_EL_3 = f"data_tau_RatioTrELdiff2TrEL2_{common_suffix}.csv"
    data_filename_EL_4 = f"data_tau_RatioTrELdiff2TrEL2byalpha2_{common_suffix}.csv"

    data_filename_BL_1 = f"data_tau_TrBLdiff2_{common_suffix}.csv"  
    data_filename_BL_2 = f"data_tau_TrBLdiff2byalpha2_{common_suffix}.csv"

    data_filename_BL_3 = f"data_tau_RatioTrBLdiff2TrBL2_{common_suffix}.csv"
    data_filename_BL_4 = f"data_tau_RatioTrBLdiff2TrBL2byalpha2_{common_suffix}.csv"

    print("\nNo noise case. \n")


if Option_Noise_Type in [1, 2, 3]:
    label_dynamic = rf"$Noise~Type = {Noise_Type_String}$, $Noise^{{Latt}} = {Noise_Value_String}$, $\alpha = {alpha_String}$,  $N = {N_T}$, $L = {L_String}$, $g^2\mu = {g2mu_String}$,$N_{{events}} = {N_Events}$"
 
    # Define common suffix for file names once
    common_suffix = f"Noise{Noise_Type_String}_Noise{Noise_Value_String}_alpha{alpha_String}_N{N_T}_L{L_String}_g2mu{g2mu_String}_Nevents{N_Events}"

    data_filename_EL_1 = f"data_tau_TrELdiff2_{common_suffix}.csv"
    data_filename_EL_2 = f"data_tau_TrELdiff2byalpha2_{common_suffix}.csv"

    data_filename_EL_3 = f"data_tau_RatioTrELdiff2TrEL2_{common_suffix}.csv"
    data_filename_EL_4 = f"data_tau_RatioTrELdiff2TrEL2byalpha2_{common_suffix}.csv"

    data_filename_BL_1 = f"data_tau_TrBLdiff2_{common_suffix}.csv"
    data_filename_BL_2 = f"data_tau_TrBLdiff2byalpha2_{common_suffix}.csv"

    data_filename_BL_3 = f"data_tau_RatioTrBLdiff2TrBL2_{common_suffix}.csv"
    data_filename_BL_4 = f"data_tau_RatioTrBLdiff2TrBL2byalpha2_{common_suffix}.csv"

    print("\nWith noise case. \n")      


    # label_dynamic = rf"$Noise~Type = {Noise_Type_String}$, $N = {N}$, $\alpha = {alpha_String}$, $m_{{noise}}^{{phy}} = {Noise_Value_String}~ g²\mu$, $N_{{events}} = {N_Events}$"
    # label_dynamic = rf"$Noise~Type = {Noise_Type_String}$, $N = {N}$, $\alpha = {alpha_String}$, $K^{{phy}} = { Noise_Value_String} \Delta k$, $N_{{events}} = {N_Events}$"
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++


if(Option_Fluctuations_EL_BL in [1, 2]):

    print("Option_Fluctuations_EL_BL =", Option_Fluctuations_EL_BL, "\n")

    print("data_filename_EL_1 : ", data_filename_EL_1)
    print("data_filename_EL_2 : ", data_filename_EL_2)
    print("data_filename_EL_3 : ", data_filename_EL_3)
    print("data_filename_EL_4 : ", data_filename_EL_4, "\n")
    print("data_filename_BL_1 : ", data_filename_BL_1)
    print("data_filename_BL_2 : ", data_filename_BL_2)
    print("data_filename_BL_3 : ", data_filename_BL_3)
    print("data_filename_BL_4 : ", data_filename_BL_4)

    df_EL_1 = pd.DataFrame({
        "tau_g2mu_Latt"       : x_tau_g2mu_Latt,
        "Tr_ELdiff2_Mean"     : y_Tr_ELdiff2_Mean,
        "Tr_ELdiff2_Variance" : y_Tr_ELdiff2_Var,
        "Tr_ELdiff2_StD"      : y_Tr_ELdiff2_StD,
        "Tr_ELdiff2_Error"    : y_Tr_ELdiff2_Error,
        "N_Events"            : N_Events,   })

    df_EL_2 = pd.DataFrame({
        "tau_g2mu_Latt"                 : x_tau_g2mu_Latt,
        "Tr_ELdiff2_by_alpha2_Mean"     : y_Tr_ELdiff2_by_alpha2_Mean,
        "Tr_ELdiff2_by_alpha2_Variance" : y_Tr_ELdiff2_by_alpha2_Var,
        "Tr_ELdiff2_by_alpha2_StD"      : y_Tr_ELdiff2_by_alpha2_StD,
        "Tr_ELdiff2_by_alpha2_Error"    : y_Tr_ELdiff2_by_alpha2_Error,
        "N_Events"                      : N_Events,   })

    df_EL_3 = pd.DataFrame({
        "tau_g2mu_Latt"                    : x_tau_g2mu_Latt,
        "Ratio_Tr_ELdiff2_Tr_EL2_Mean"     : y_Ratio_Tr_ELdiff2_Tr_EL2_Mean,
        "Ratio_Tr_ELdiff2_Tr_EL2_Variance" : y_Ratio_Tr_ELdiff2_Tr_EL2_Var,
        "Ratio_Tr_ELdiff2_Tr_EL2_StD"      : y_Ratio_Tr_ELdiff2_Tr_EL2_StD,
        "Ratio_Tr_ELdiff2_Tr_EL2_Error"    : y_Ratio_Tr_ELdiff2_Tr_EL2_Error,
        "N_Events"                         : N_Events,   })    

    df_EL_4 = pd.DataFrame({
        "tau_g2mu_Latt"                              : x_tau_g2mu_Latt,
        "Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Mean"     : y_Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Mean,
        "Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Variance" : y_Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Var,
        "Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_StD"      : y_Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_StD,
        "Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Error"    : y_Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Error,
        "N_Events"                                   : N_Events,   })


    df_BL_1 = pd.DataFrame({
        "tau_g2mu_Latt"       : x_tau_g2mu_Latt,
        "Tr_BLdiff2_Mean"     : y_Tr_BLdiff2_Mean,
        "Tr_BLdiff2_Variance" : y_Tr_BLdiff2_Var,
        "Tr_BLdiff2_StD"      : y_Tr_BLdiff2_StD,
        "Tr_BLdiff2_Error"    : y_Tr_BLdiff2_Error,
        "N_Events"            : N_Events,   })

    df_BL_2 = pd.DataFrame({
        "tau_g2mu_Latt"                 : x_tau_g2mu_Latt,
        "Tr_BLdiff2_by_alpha2_Mean"     : y_Tr_BLdiff2_by_alpha2_Mean,
        "Tr_BLdiff2_by_alpha2_Variance" : y_Tr_BLdiff2_by_alpha2_Var,
        "Tr_BLdiff2_by_alpha2_StD"      : y_Tr_BLdiff2_by_alpha2_StD,
        "Tr_BLdiff2_by_alpha2_Error"    : y_Tr_BLdiff2_by_alpha2_Error,
        "N_Events"                      : N_Events,   })

    df_BL_3 = pd.DataFrame({
        "tau_g2mu_Latt"                    : x_tau_g2mu_Latt,
        "Ratio_Tr_BLdiff2_Tr_BL2_Mean"     : y_Ratio_Tr_BLdiff2_Tr_BL2_Mean,
        "Ratio_Tr_BLdiff2_Tr_BL2_Variance" : y_Ratio_Tr_BLdiff2_Tr_BL2_Var,
        "Ratio_Tr_BLdiff2_Tr_BL2_StD"      : y_Ratio_Tr_BLdiff2_Tr_BL2_StD,
        "Ratio_Tr_BLdiff2_Tr_BL2_Error"    : y_Ratio_Tr_BLdiff2_Tr_BL2_Error,
        "N_Events"                         : N_Events,   })    

    df_BL_4 = pd.DataFrame({
        "tau_g2mu_Latt"                              : x_tau_g2mu_Latt,
        "Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Mean"     : y_Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Mean,
        "Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Variance" : y_Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Var,
        "Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_StD"      : y_Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_StD,
        "Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Error"    : y_Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Error,
        "N_Events"                                   : N_Events,   })


    df_EL_1.to_csv(data_filename_EL_1, index=False)                                                                                 # Save the DataFrame to a CSV file
    df_EL_1 = pd.read_csv(data_filename_EL_1)                                                                                       # Read the CSV file into a DataFrame

    df_EL_2.to_csv(data_filename_EL_2, index=False)
    df_EL_2 = pd.read_csv(data_filename_EL_2)

    df_EL_3.to_csv(data_filename_EL_3, index=False)
    df_EL_3 = pd.read_csv(data_filename_EL_3)

    df_EL_4.to_csv(data_filename_EL_4, index=False)
    df_EL_4 = pd.read_csv(data_filename_EL_4)



    df_BL_1.to_csv(data_filename_BL_1, index=False)                                                                                 
    df_BL_1 = pd.read_csv(data_filename_BL_1)                                                                                     

    df_BL_2.to_csv(data_filename_BL_2, index=False)
    df_BL_2 = pd.read_csv(data_filename_BL_2)

    df_BL_3.to_csv(data_filename_BL_3, index=False)
    df_BL_3 = pd.read_csv(data_filename_BL_3)

    df_BL_4.to_csv(data_filename_BL_4, index=False)
    df_BL_4 = pd.read_csv(data_filename_BL_4)




    #           Plot    g²μτ    vs      Tr(E′η - Eη)²    
    plt.figure(figsize=(14, 8)) 
    plt.errorbar( x   =  df_EL_1["tau_g2mu_Latt"],     y  =  df_EL_1["Tr_ELdiff2_Mean"],     yerr = df_EL_1["Tr_ELdiff2_Error"],
                label = label_dynamic,  
                errorevery = 50,  
                linewidth = 1, 
                linestyle = "solid", 
                color = "red", 
                ecolor = "blue", 
                elinewidth = 1,  
                capsize = 3,        
                capthick = 1)
    plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}$")      
    plt.ylabel(r"$\mathrm{ Tr~(E'_{\eta} - E_{\eta})^2}$")
    plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
    #plt.xlim(0.0, 200)                                                                                                       
    #plt.ylim(0.0, 1)                                                                                         
    plt.legend()
    plt.grid()
    plt.show()


    #           Plot    g²μτ    vs      1/α²  Tr(E′η - Eη)²     
    plt.errorbar( x   =  df_EL_2["tau_g2mu_Latt"],     y  =  df_EL_2["Tr_ELdiff2_by_alpha2_Mean"],     yerr = df_EL_2["Tr_ELdiff2_by_alpha2_Error"],
                label = label_dynamic,  
                errorevery = 50,  
                linewidth = 1, 
                linestyle = "solid", 
                color = "red", 
                ecolor = "blue", 
                elinewidth = 1,  
                capsize = 3,        
                capthick = 1)
    plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2} ~ \mathrm{Tr~(E'_{\eta} - E_{\eta})^2}$")      
    plt.ylabel(r"$\frac{1}{\alpha^2} ~ \mathrm{ Tr~(E'_{\eta} - E_{\eta})^2}$")
    plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
    #plt.xlim(0.0, 200)                                                                                                       
    #plt.ylim(0.0, 1)                                                                                         
    plt.legend()
    plt.show()


    #           Plot    g²μτ    vs      Tr(E′η - Eη)² / Tr(Eη²)   
    plt.errorbar( x   =  df_EL_3["tau_g2mu_Latt"],     y  =  df_EL_3["Ratio_Tr_ELdiff2_Tr_EL2_Mean"],     yerr = df_EL_3["Ratio_Tr_ELdiff2_Tr_EL2_Error"],
                label = label_dynamic,  
                errorevery = 50,  
                linewidth = 1, 
                linestyle = "solid", 
                color = "red", 
                ecolor = "blue", 
                elinewidth = 1,  
                capsize = 3,        
                capthick = 1)
    plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\mathrm{\frac{Tr(~E'_{\eta} - E_{\eta})^2}{Tr~(E_{\eta}^2)} }$")            
    plt.ylabel(r"$\mathrm{\frac{Tr~(E'_{\eta} - E_{\eta})^2}{Tr~(E_{\eta}^2)}}$")
    plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
    #plt.xlim(0.0, 200)                                                                                                       
    #plt.ylim(0.0, 1)                                                                                           
    plt.legend()
    plt.show()


    #           Plot    g²μτ    vs      1/α²  Tr(E′η - Eη)² / Tr(Eη²)   
    plt.errorbar( x   =  df_EL_4["tau_g2mu_Latt"],     y  =  df_EL_4["Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Mean"],     yerr = df_EL_4["Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Error"],
                label = label_dynamic,  
                errorevery = 50,  
                linewidth = 1, 
                linestyle = "solid", 
                color = "red", 
                ecolor = "blue", 
                elinewidth = 1,  
                capsize = 3,     
                capthick = 1)
    plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2} ~ \mathrm{\frac{Tr(~E'_{\eta} - E_{\eta})^2}{Tr~(E_{\eta}^2)} }$")            
    plt.ylabel(r"$\frac{1}{\alpha^2} ~ \mathrm{\frac{Tr~(E'_{\eta} - E_{\eta})^2}{Tr~(E_{\eta}^2)}}$")
    plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
    #plt.xlim(0.0, 200)                                                                                                       
    #plt.ylim(0.0, 1)                                                                                           
    plt.legend()
    plt.show()





    #           Plot    g²μτ    vs      Tr(B′η - Bη)²     
    plt.errorbar( x   =  df_BL_1["tau_g2mu_Latt"],     y  =  df_BL_1["Tr_BLdiff2_Mean"],     yerr = df_BL_1["Tr_BLdiff2_Error"],
                label = label_dynamic,  
                errorevery = 50,  
                linewidth = 1, 
                linestyle = "solid", 
                color = "red", 
                ecolor = "blue", 
                elinewidth = 1,  
                capsize = 3,        
                capthick = 1)
    plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $ \mathrm{Tr~(B'_{\eta} - B_{\eta})^2}$")      
    plt.ylabel(r"$ \mathrm{ Tr~(B'_{\eta} - B_{\eta})^2}$")
    plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
    #plt.xlim(0.0, 200)                                                                                                       
    #plt.ylim(0.0, 1)                                                                                         
    plt.legend()
    plt.show()


    #           Plot    g²μτ    vs      1/α²  Tr(B′η - Bη)²     
    plt.errorbar( x   =  df_BL_2["tau_g2mu_Latt"],     y  =  df_BL_2["Tr_BLdiff2_by_alpha2_Mean"],     yerr = df_BL_2["Tr_BLdiff2_by_alpha2_Error"],
                label = label_dynamic,  
                errorevery = 50,  
                linewidth = 1, 
                linestyle = "solid", 
                color = "red", 
                ecolor = "blue", 
                elinewidth = 1,  
                capsize = 3,        
                capthick = 1)
    plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2} ~ \mathrm{Tr~(B'_{\eta} - B_{\eta})^2}$")      
    plt.ylabel(r"$\frac{1}{\alpha^2} ~ \mathrm{ Tr~(B'_{\eta} - B_{\eta})^2}$")
    plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
    #plt.xlim(0.0, 200)                                                                                                       
    #plt.ylim(0.0, 1)                                                                                         
    plt.legend()
    plt.show()


    #           Plot    g²μτ    vs      Tr(B′η - Bη)² / Tr(Bη²)   
    plt.errorbar( x   =  df_BL_3["tau_g2mu_Latt"],     y  =  df_BL_3["Ratio_Tr_BLdiff2_Tr_BL2_Mean"],     yerr = df_BL_3["Ratio_Tr_BLdiff2_Tr_BL2_Error"],
                label = label_dynamic,  
                errorevery = 50,  
                linewidth = 1, 
                linestyle = "solid", 
                color = "red", 
                ecolor = "blue", 
                elinewidth = 1,  
                capsize = 3,        
                capthick = 1)
    plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\mathrm{\frac{Tr(~B'_{\eta} - B_{\eta})^2}{Tr~(B_{\eta}^2)} }$")            
    plt.ylabel(r"$\mathrm{\frac{Tr~(B'_{\eta} - B_{\eta})^2}{Tr~(B_{\eta}^2)}}$")
    plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
    #plt.xlim(0.0, 200)                                                                                                       
    #plt.ylim(0.0, 1)                                                                                           
    plt.legend()
    plt.show()


    #           Plot    g²μτ    vs      1/α²  Tr(B′η - Bη)² / Tr(Bη²)   
    plt.errorbar( x   =  df_BL_4["tau_g2mu_Latt"],     y  =  df_BL_4["Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Mean"],     yerr = df_BL_4["Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Error"],
                label = label_dynamic,  
                errorevery = 50,  
                linewidth = 1, 
                linestyle = "solid", 
                color = "red", 
                ecolor = "blue", 
                elinewidth = 1,  
                capsize = 3,     
                capthick = 1)
    plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2} ~ \mathrm{\frac{Tr(~B'_{\eta} - B_{\eta})^2}{Tr~(B_{\eta}^2)} }$")            
    plt.ylabel(r"$\frac{1}{\alpha^2} ~ \mathrm{\frac{Tr~(B'_{\eta} - B_{\eta})^2}{Tr~(B_{\eta}^2)}}$")
    plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
    #plt.xlim(0.0, 200)                                                                                                       
    #plt.ylim(0.0, 1)                                                                                           
    plt.legend()
    plt.show()



else:
    print("Option_Fluctuations_EL_BL =", Option_Fluctuations_EL_BL, "\n")
    print("\nError: Option_Fluctuations_EL_BL not recognized")
    sys.exit(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # ----------------------- Saving data to a CSV file and plotting from file using pandas -----------------------
# ----> 3 x_tau_g2mu_Latt    =  tau_g2mu_Latt
#       5 y_Tr_ELdiff2_Mean  =  Glasma["Tr_ELdiff2_Mean"]
#       6 y_Tr_ELdiff2_Var   =  Glasma["Tr_ELdiff2_Variance"]
#
# NameError: name 'tau_g2mu_Latt' is not defined

# %%
#  ============================================== Plot electric field fluctuations vs time ===============================================

#           Plot    g²μτ    vs      Tr(E′η - Eη)²    
plt.errorbar( x = x_tau_g2mu_Latt,      y = y_Tr_ELdiff2_Mean,      yerr = y_Tr_ELdiff2_Error, 
             label = label_dynamic,  
             errorevery = 50,  
             linewidth = 1, 
             linestyle = "solid", 
             color = "red", 
             ecolor = "blue", 
             elinewidth = 1,  
             capsize = 3,        
             capthick = 1)
plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}$")            
plt.ylabel(r"$\mathrm{ Tr~(E'_{\eta} - E_{\eta})^2}$")
plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
#plt.xlim(0.0, 200)                                                                                                       
#plt.ylim(0.0, 1)  
plt.legend()
plt.grid(True)
#plt.tight_layout()
plt.show()


#           Plot    g²μτ    vs      1/α²  Tr(E′η - Eη)²     
plt.errorbar( x = x_tau_g2mu_Latt,      y = y_Tr_ELdiff2_by_alpha2_Mean,        yerr = y_Tr_ELdiff2_by_alpha2_Error, 
             label = label_dynamic,  
             errorevery = 50,  
             linewidth = 1, 
             linestyle = "solid", 
             color = "red", 
             ecolor = "blue", 
             elinewidth = 1,  
             capsize = 3,        
             capthick = 1)
plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2} ~ \mathrm{Tr~(E'_{\eta} - E_{\eta})^2}$")      
plt.ylabel(r"$\frac{1}{\alpha^2} ~ \mathrm{ Tr~(E'_{\eta} - E_{\eta})^2}$")
plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
#plt.xlim(0.0, 200)                                                                                                       
#plt.ylim(0.0, 1)   
plt.legend()
plt.grid(True)
#plt.tight_layout()
plt.show()


#           Plot    g²μτ    vs      Tr(E′η - Eη)² / Tr(Eη²)   
plt.errorbar( x = x_tau_g2mu_Latt,      y = y_Ratio_Tr_ELdiff2_Tr_EL2_Mean,     yerr = y_Ratio_Tr_ELdiff2_Tr_EL2_Error,
             label = label_dynamic,  
             errorevery = 50,  
             linewidth = 1, 
             linestyle = "solid", 
             color = "red", 
             ecolor = "blue", 
             elinewidth = 1,  
             capsize = 3,        
             capthick = 1)
plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\mathrm{\frac{Tr(~E'_{\eta} - E_{\eta})^2}{Tr~(E_{\eta}^2)} }$")            
plt.ylabel(r"$\mathrm{\frac{Tr~(E'_{\eta} - E_{\eta})^2}{Tr~(E_{\eta}^2)}}$")
plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
#plt.xlim(0.0, 200)                                                                                                       
#plt.ylim(0.0, 1)   
plt.legend()
plt.grid(True)
#plt.tight_layout()
plt.show()


#           Plot    g²μτ    vs      1/α²  Tr(E′η - Eη)² / Tr(Eη²)   
plt.errorbar( x = x_tau_g2mu_Latt,      y = y_Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Mean,       yerr = y_Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Error, 
             label = label_dynamic,  
             errorevery = 50,  
             linewidth = 1, 
             linestyle = "solid", 
             color = "red", 
             ecolor = "blue", 
             elinewidth = 1,  
             capsize = 3,     
             capthick = 1)
plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2} ~ \mathrm{\frac{Tr(~E'_{\eta} - E_{\eta})^2}{Tr~(E_{\eta}^2)} }$")            
plt.ylabel(r"$\frac{1}{\alpha^2} ~ \mathrm{\frac{Tr~(E'_{\eta} - E_{\eta})^2}{Tr~(E_{\eta}^2)}}$")
plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
#plt.xlim(0.0, 200)                                                                                                       
#plt.ylim(0.0, 1) 
plt.legend()
plt.grid(True)
#plt.tight_layout()
plt.show()




#  ============================================== Plot magnetic field fluctuations vs time ===============================================

#           Plot    g²μτ    vs      Tr(B′η - Bη)²    
plt.errorbar( x = x_tau_g2mu_Latt,      y = y_Tr_BLdiff2_Mean,      yerr = y_Tr_BLdiff2_Error, 
             label = label_dynamic,  
             errorevery = 50,  
             linewidth = 1, 
             linestyle = "solid", 
             color = "red", 
             ecolor = "blue", 
             elinewidth = 1,  
             capsize = 3,        
             capthick = 1)
plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\mathrm{Tr~(B'_{\eta} - B_{\eta})^2}$")            
plt.ylabel(r"$\mathrm{ Tr~(B'_{\eta} - B_{\eta})^2}$")
plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
#plt.xlim(0.0, 200)                                                                                                       
#plt.ylim(0.0, 1)   
plt.legend()
plt.grid(True)
#plt.tight_layout()
plt.show()


#           Plot    g²μτ    vs      1/α²  Tr(B′η - Bη)²     
plt.errorbar( x = x_tau_g2mu_Latt,      y = y_Tr_BLdiff2_by_alpha2_Mean,        yerr = y_Tr_BLdiff2_by_alpha2_Error, 
             label = label_dynamic,  
             errorevery = 50,  
             linewidth = 1, 
             linestyle = "solid", 
             color = "red", 
             ecolor = "blue", 
             elinewidth = 1,  
             capsize = 3,        
             capthick = 1)
plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2} ~ \mathrm{Tr~(B'_{\eta} - B_{\eta})^2}$")      
plt.ylabel(r"$\frac{1}{\alpha^2} ~ \mathrm{ Tr~(B'_{\eta} - B_{\eta})^2}$")
plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
#plt.xlim(0.0, 200)                                                                                                       
#plt.ylim(0.0, 1) 
plt.legend()
plt.grid(True)
#plt.tight_layout()
plt.show()


#           Plot    g²μτ    vs      Tr(B′η - Bη)² / Tr(Bη²)   
plt.errorbar( x = x_tau_g2mu_Latt,      y = y_Ratio_Tr_BLdiff2_Tr_BL2_Mean,     yerr = y_Ratio_Tr_BLdiff2_Tr_BL2_Error,
             label = label_dynamic,  
             errorevery = 50,  
             linewidth = 1, 
             linestyle = "solid", 
             color = "red", 
             ecolor = "blue", 
             elinewidth = 1,  
             capsize = 3,        
             capthick = 1)
plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\mathrm{\frac{Tr(~B'_{\eta} - B_{\eta})^2}{Tr~(B_{\eta}^2)} }$")            
plt.ylabel(r"$\mathrm{\frac{Tr~(B'_{\eta} - B_{\eta})^2}{Tr~(B_{\eta}^2)}}$")
plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
#plt.xlim(0.0, 200)                                                                                                       
#plt.ylim(0.0, 1)    
plt.legend()
plt.grid(True)
#plt.tight_layout()
plt.show()


#           Plot    g²μτ    vs      1/α²  Tr(B′η - Bη)² / Tr(Bη²)   
plt.errorbar( x = x_tau_g2mu_Latt,      y = y_Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Mean,       yerr = y_Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2_Error, 
             label = label_dynamic,  
             errorevery = 50,  
             linewidth = 1, 
             linestyle = "solid", 
             color = "red", 
             ecolor = "blue", 
             elinewidth = 1,  
             capsize = 3,     
             capthick = 1)
plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2} ~ \mathrm{\frac{Tr(~B'_{\eta} - B_{\eta})^2}{Tr~(B_{\eta}^2)} }$")            
plt.ylabel(r"$\frac{1}{\alpha^2} ~ \mathrm{\frac{Tr~(B'_{\eta} - B_{\eta})^2}{Tr~(B_{\eta}^2)}}$")
plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
#plt.xlim(0.0, 200)                                                                                                       
#plt.ylim(0.0, 1)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 #  ============================================== Plot electric field fluctuations vs time ===============================================
#       2
#       3 #           Plot    g²μτ    vs      Tr(E′η - Eη)²
# ----> 4 plt.errorbar( x = x_tau_g2mu_Latt,      y = y_Tr_ELdiff2_Mean,      yerr = y_Tr_ELdiff2_Error,
#       5              label = label_dynamic,
#       6              errorevery = 50,
#       7              linewidth = 1,
#       8              linestyle = "solid",
#       9              color = "red",
#      10              ecolor = "blue",
#      11              elinewidth = 1,
#      12              capsize = 3,
#      13              capthick = 1)
#      14 plt.title(r"$(g^2 \mu \tau)^{Latt}$ vs $\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}$")
# ...

# %%
# CURVE FITTING

import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit



# +++++++++++++++++++++++++++++++++++++++++++++ Define Exponential Function +++++++++++++++++++++++++++++++++++++++++++++ #
def exponential_fit_customized(x, a, b):
    x = np.sqrt(x)
    y = a * np.exp(b * x)
    return y
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ #



# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! #
# Define the ranges to test
x_min = np.arange(5, 101, 25)                                # [5, 10, ..., 95, 100]
x_max = np.arange(30, 405, 25)                               # [50, 55, ..., 300]

# x_min = np.arange(5, 101, 50 )                                # [5, 10, ..., 95, 100]
# # x_max = np.arange(50, 401, 100)
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! #



data_filename_EL_2 = f"data_tau_TrELdiff2byalpha2_{common_suffix}.csv"
x2_data  = df_EL_2["tau_g2mu_Latt"]
y2_data  = df_EL_2["Tr_ELdiff2_by_alpha2_Mean"]
y2_error = df_EL_2["Tr_ELdiff2_by_alpha2_Error"]




# data_filename_EL_2 = f"data_tau_RatioTrELdiff2TrEL2byalpha2_{common_suffix}.csv"
# x2_data  = df_EL_4["tau_g2mu_Latt"]
# y2_data  = df_EL_4["Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Mean"]
# y2_error = df_EL_4["Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2_Error"]

# Create a table to store results
results_table = []

plt.figure(figsize=(14, 8))


for x_min_fit in x_min:
    for x_max_fit in x_max:

        if x_min_fit >= x_max_fit:              # Skip invalid ranges
            continue
                                        
        # Filter data in current range using mask 
        mask = (x2_data >= x_min_fit) & (x2_data <= x_max_fit)                            
        x_fit = x2_data[mask]
        y_fit = y2_data[mask]
        y_error_fit = y2_error[mask]

        sigma = y_error_fit
        p0 = [0.0004, 0.01]  

                                                                # Perform the fit on the filtered data
        fitted_parameters, covariance_matrix = curve_fit(exponential_fit_customized, x_fit, y_fit, p0=p0, maxfev=50000, sigma=sigma, absolute_sigma=True)
        a, b = fitted_parameters                                                            # Get optimal parameters for fitting
        a_error, b_error = np.sqrt(np.diag(covariance_matrix))                              # Standard errors for parameters a and b


        # Generate points for the fitted curve (only in the fitting range)
        x_fit_curve = x_fit             
        y_fit_curve = exponential_fit_customized(x_fit_curve, a, b)

        residuals = y_fit - y_fit_curve                                 # Calculate residuals (actual_data - fitted_data)

        chi_sq = np.sum((residuals / sigma) ** 2)                       # Compute χ²

        # Compute reduced χ²
        N_data_points = len(x_fit_curve)
        N_parameters = 2                                             # 2 = No. of parameters (a,b)
        dof = N_data_points - N_parameters    
        reduced_chi_sq = chi_sq / dof
                                        
        # Calculate chi-squared
        residuals = y_fit - exponential_fit_customized(x_fit, a, b)
        chi_sq = np.sum((residuals/sigma)**2)
        dof = len(x_fit) - 2
        reduced_chi_sq = chi_sq/dof

        # Add new column for the criterion
        range_x_sqrt = 0.4*(np.sqrt(x_max_fit) - np.sqrt(x_min_fit))



                                        
        # Store results
        results_table.append({  'N' : N_T,
                                'Noise_value': Noise_Value_String,
                                'alpha': alpha_String,                                     
                                                        'x_min': x_min_fit,
                                                        'x_max': x_max_fit,
                                                        'a': a,
                                                        'a_error': a_error,
                                                        'b': b,
                                                        'b_error': b_error,
                                                        'chi_sq': chi_sq,
                                                        'reduced_chi_sq': reduced_chi_sq,
                                                        'range_x_sqrt': range_x_sqrt })
                   

        # Plot the fitted curve (in different fitting range)
                                
        # Fit_label = (rf"Fit($x \in [{x_min_fit}, {x_max_fit}]$): " rf"$y = {a:.5f}e^{{{b:.5f}\sqrt{{x}}}}$" + "   " + rf"$\chi^2/\mathrm{{dof}} = {reduced_chi_sq:.5f}$" + "  " + rf"$Noise~Type = {noise_type}$, $N = {N}$, $(K/g^2\mu)^{{Latt}} = {Noisevalue_by_g2mu_Latt_str}$,  $N_{{events}} = {N_events}$")
        # plt.plot(x_fit_curve, y_fit_curve, label=Fit_label,  linewidth=1, color='green')
                                # plt.scatter(x_fit_curve, y_fit_curve, label=Fit_label)





# ++++++++++++++++++++++++++++++++++++++++++++++++ Create and display results table ++++++++++++++++++++++++++++++++++++++++++++++++
results_df = pd.DataFrame(results_table)

Fit_results_filename = f"Fits_all_{data_filename_EL_2}"


formatted_output = results_df.to_string(   index=False,  justify='center',  col_space=12  )#,  float_format="%.4e"   )
with open(f"{Fit_results_filename}", "w") as f:
    f.write(formatted_output)

columns_order = ["N", "Noise_value", "alpha", "x_min", "x_max", "a", "a_error", "b", "b_error", "chi_sq", "reduced_chi_sq", "b_error", "range_x_sqrt"]

# print("\n\nResults Table: \n")
# print(results_df[columns_order].to_string(index=False,  justify='center', float_format="{:,.4e}".format))









#  Keep only statistically acceptable fits for which Reduced χ² < 1.0
acceptable_fits_ChiSq = results_df[results_df["reduced_chi_sq"] < 1.0].copy()

print("Acceptable fits for which Reduced χ² < 1.0 : \n")
print(acceptable_fits_ChiSq[columns_order].to_string(index=False,  justify='center'))#, float_format="{:,.4e}".format))    

if acceptable_fits_ChiSq.empty:
    print("No fits have reduced χ² < 1.0 !!! \nThink what to do now :( \nNext cell will give error now.")
else:

    # Sort acceptable fits by b_error in ascending order
    best_fits = (acceptable_fits_ChiSq.sort_values(["b_error"]))
    print("\n\nSorting of acceptable fits for which χ² < 1.0 in order of ascending b_error: \n")
    print(best_fits[columns_order].to_string(index=False,  justify='center'))#, float_format="{:,.4e}".format)) 


    # write a separate file with name "Best_fits_Noise....."
    Best_fits_filename = f"Fits_Best_{data_filename_EL_2}"



    # Save to a text file
    formatted_output = best_fits.to_string(   index=False,  justify='center',  col_space=12)#,  float_format="%.4e"   )
    with open(f"{Best_fits_filename}", "w") as f:
        f.write(formatted_output)



    # =========================================== Best of Best Fits =========================================== #
    # Select best fits based on the new criterion: range_x_sqrt = 0.4*(√x_max - √x_min) ≥ some_number

    some_number = 1.5
    
    bestof_bestfits = best_fits[best_fits["range_x_sqrt"] >= some_number].copy()  # Filter based on the new criterion
    
    print("\n\nBest of best fits (χ² < 1.0, sorted by b_error, and 0.4*(√x_max-√x_min) ≥ some_number): \n")
    print(bestof_bestfits[columns_order].to_string(index=False, justify='center'))

    if bestof_bestfits.empty:
        print("\nNo fits satisfy all criteria (χ² < 1.0 AND 0.4*(√x_max-√x_min) ≥ 1.5)!")
        print("Using the best fit from χ² < 1.0 sorted by b_error instead.")
        bestof_bestfits = best_fits.head(1)  # Take the top one if none satisfy the sqrt criterion
    else:

        # Sort first by b_error (ascending), then by range_x_sqrt (descending)
        bestof_bestfits = bestof_bestfits.sort_values(['b_error', 'range_x_sqrt'], ascending=[True, False])
               
        #bestof_bestfits = bestof_bestfits.sort_values('b_error')
        #bestof_bestfits = bestof_bestfits.sort_values('b_error').head(1)   # If multiple fits satisfy, take the one with smallest b_error 

           

    # Write the best of best fits to a file
    Best_of_best_data_fit_filename = f"Fits_Bestofbest_{data_filename_EL_2}" 
    


    formatted_output = bestof_bestfits.to_string(index=False, justify='center', col_space=12)
    with open(f"{Best_of_best_data_fit_filename}", "w") as f:
        f.write(formatted_output)





# Best_of_best_data_fit_filename = f"Best_of_best_data_fit_Noise{noise_type}_N{N}_Nevents{N_events}_Noise{Noisevalue_by_g2mu_Latt_str}_alpha{alpha_str}.txt" 



best_fits_df = pd.read_csv(Best_of_best_data_fit_filename, sep='\s+')

# Get the best fit parameters (first row)
best_fit_row = best_fits_df.iloc[0]
x_min_best = best_fit_row['x_min']
x_max_best = best_fit_row['x_max']
a_best = best_fit_row['a']
b_best = best_fit_row['b']
reduced_chi_sq_best = best_fit_row['reduced_chi_sq']

            
# Create x values for the best fit curve
x_fit = np.linspace(x_min_best, x_max_best, 100)
y_fit = exponential_fit_customized(x_fit, a_best, b_best)
                        
print(x_min_best,  x_max_best, a_best , b_best , reduced_chi_sq_best)


                        
best_fit_label = (rf"Best Fit($x \in [{x_min_best}, {x_max_best}]$): " 
                                        rf"$y = {a_best:.5f}e^{{{b_best:.5f}\sqrt{{x}}}}$" + "   " 
                                        rf"$\chi^2/\mathrm{{dof}} = {reduced_chi_sq_best:.5f}$"  )
                                        #+ "   "  rf"$(m/g^2\mu)^{{Latt}} = {Noisevalue_by_g2mu_Latt_str}$" )
                        
plt.errorbar(x2_data, y2_data, y2_error, label=label_dynamic,
                                        errorevery=100,
                                        linestyle='--',                                        # none: No connecting lines
                                         color = "red", 
                                        #ecolor='blue',
                                        elinewidth=1,
                                        capsize=2,
                                    )
                        #plt.plot(x_data, y_data,  label=plot_label, linestyle='--', color=current_color )

plt.plot(x_fit, y_fit,  label=best_fit_label, linewidth=2, color="blue")

plt.ylabel(r"$\frac{1}{\alpha^2} ~ \mathrm{ Tr~(E'_{\eta} - E_{\eta})^2}$")
plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")  
#plt.xlim(0.0, 200)                                                                                                       
#plt.ylim(0.0, 1)                                                                                         

plt.legend()
plt.grid(True)
#plt.tight_layout()
plt.show()

# %%
# =============================================================================================================
#                          All possible plot configurations  
# =============================================================================================================
Plot_Configurations = [             
    # (data_key, title, y_label)
    
    ("Tr_ELdiff2",                                                                              # data_key 
     r"$(g^2 \mu \tau)^{Latt}$ vs $\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}$",                      # title 
     r"$\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}$"),                                                # y_label
    
    ("Tr_ELdiff2_by_alpha2", 
     r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2}\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}$", 
     r"$\frac{1}{\alpha^2}\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}$"),
    
    ("Ratio_Tr_ELdiff2_Tr_EL2", 
     r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}}{\mathrm{Tr~(E_{\eta}^2)}}$", 
     r"$\frac{\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}}{\mathrm{Tr~(E_{\eta}^2)}}$"),
    
    ("Ratio_Tr_ELdiff2_Tr_EL2_by_alpha2", 
     r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2}\frac{\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}}{\mathrm{Tr~(E_{\eta}^2)}}$", 
     r"$\frac{1}{\alpha^2}\frac{\mathrm{Tr~(E'_{\eta} - E_{\eta})^2}}{\mathrm{Tr~(E_{\eta}^2)}}$"),
    
    ("Tr_BLdiff2", 
     r"$(g^2 \mu \tau)^{Latt}$ vs $\mathrm{Tr~(B'_{\eta} - B_{\eta})^2}$", 
     r"$\mathrm{Tr~(B'_{\eta} - B_{\eta})^2}$"),
    
    ("Tr_BLdiff2_by_alpha2", 
     r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2}\mathrm{Tr~(B'_{\eta} - B_{\eta})^2}$", 
     r"$\frac{1}{\alpha^2}\mathrm{Tr~(B'_{\eta} - B_{\eta})^2}$"),
    
    ("Ratio_Tr_BLdiff2_Tr_BL2", 
     r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{\mathrm{Tr~(B'_{\eta} - B_{\eta})^2}}{\mathrm{Tr~(B_{\eta}^2)}}$", 
     r"$\frac{\mathrm{Tr~(B'_{\eta} - B_{\eta})^2}}{\mathrm{Tr~(B_{\eta}^2)}}$"),
    
    ("Ratio_Tr_BLdiff2_Tr_BL2_by_alpha2", 
     r"$(g^2 \mu \tau)^{Latt}$ vs $\frac{1}{\alpha^2}\frac{\mathrm{Tr~(B'_{\eta} - B_{\eta})^2}}{\mathrm{Tr~(B_{\eta}^2)}}$", 
     r"$\frac{1}{\alpha^2}\frac{\mathrm{Tr~(B'_{\eta} - B_{\eta})^2}}{\mathrm{Tr~(B_{\eta}^2)}}$")
]
# =============================================================================================================
# =============================================================================================================



# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#           Function Create_Dataframe: To create data frames for a given data key using pandas 
#           Function Save_and_Reload_to_Read: To save DataFrame to a file and reload it to read the file for plotting
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
def Create_Dataframe(x_data, Glasma_for_y_data, data_key, N_Events):           
    
    return pd.DataFrame({
        "tau_g2mu_Latt"         :       x_data,
        f"{data_key}_Mean"      :       Glasma_for_y_data[f"{data_key}_Mean"],
        f"{data_key}_Variance"  :       Glasma_for_y_data[f"{data_key}_Variance"],
        f"{data_key}_StD"       :       Glasma_for_y_data[f"{data_key}_StD"],
        f"{data_key}_Error"     :       Glasma_for_y_data[f"{data_key}_Error"],
        "N_Events"              :       N_Events
    })


def Save_and_Reload_to_Read(df, filename):
    df.to_csv(filename, index=False)
    return pd.read_csv(filename)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++



# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#                                   Function Create_Plot: To plot
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
def Create_Plot(df, key, title, y_label, label_dynamic):
    plt.figure(figsize=(14, 8))
    plt.errorbar(
                    x           =   df["tau_g2mu_Latt"],
                    y           =   df[f"{key}_Mean"],
                    yerr        =   df[f"{key}_Error"],
                    label       =   label_dynamic,
                    errorevery  =   50,
                    linewidth   =   1,
                    linestyle   =   "solid",
                    color       =   "red",
                    ecolor      =   "blue",
                    elinewidth  =   1,
                    capsize     =   3,
                    capthick    =   1
    )
    plt.title(title)
    plt.ylabel(y_label)
    plt.xlabel(r"$(g^2 \mu \tau)^{Latt}$")
    plt.legend()
    plt.grid()
    plt.show()
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++


# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#                                                                                   Main Execution     
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# Generate common suffix and label
if Option_Noise_Type == 0:
    label_dynamic = rf"$Noise~Type = {Noise_Type_String}$, $\alpha = {alpha_String}$, $N = {N_T}$, $L = {L_String}~fm$, $g^2\mu = {g2mu_String}~GeV$, $N_{{events}} = {N_Events}$"
    common_suffix = f"Noise{Noise_Type_String}_alpha{alpha_String}_N{N_T}_L{L_String}_g2mu{g2mu_String}_Nevents{N_Events}"
    print("No noise case.\n")
elif Option_Noise_Type in [1, 2, 3]:
    label_dynamic = rf"$Noise~Type = {Noise_Type_String}$, $Noise^{{Latt}} = {Noise_Value_String}$, $\alpha = {alpha_String}$, $N = {N_T}$, $L = {L_String}~fm$, $g^2\mu = {g2mu_String}~GeV$, $N_{{events}} = {N_Events}$"
    common_suffix = f"Noise{Noise_Type_String}_Noise{Noise_Value_String}_alpha{alpha_String}_N{N_T}_L{L_String}_g2mu{g2mu_String}_Nevents{N_Events}"
    print("With noise case.\n")
else:
    print(f"Error: Option_Noise_Type = {Option_Noise_Type} not recognized")   
    sys.exit(1)


# Process data and create plots
if Option_Fluctuations_EL_BL in [1, 2]:

    print(f"Option_Fluctuations_EL_BL = {Option_Fluctuations_EL_BL}\n")
    
    for data_key, title, y_label in Plot_Configurations:

        filename = f"Data_tau_{data_key}_{common_suffix}.csv"                   # Generate filename
        print(f"Processing file: {filename}")
        
        df = Create_Dataframe(tau_g2mu_Latt, Glasma, data_key, N_Events)        # Create DataFrame
        df = Save_and_Reload_to_Read(df, filename)                              # Save DataFrame        
        
        #Create_Plot(df, data_key, title, y_label, label_dynamic)                # Create plot      #Uncomment later on
        
    print("All data files saved and plots generated successfully!")
    
else:
    print(f"Error: Option_Fluctuations_EL_BL = {Option_Fluctuations_EL_BL} not recognized")
    sys.exit(1)

# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!





# ===================================================================================================================================================== #
# ===================================================================================================================================================== #



print("\nHello, this code is done! Hurray!!!")


print("\nHello, the time now is:", datetime.now())
